# %%
from pycaret.classification import *
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score, cohen_kappa_score, matthews_corrcoef
import time

# %% [markdown]
# ## 4 sensors

# %%
data = pd.read_excel('/home/soham/Desktop/GitHub/BTP/data/4sensors/polynomial_data.xlsx')
data = data[['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Label']]

clf_setup = setup(data=data, target='Label', session_id=123, preprocess=True, verbose=False)
comparison_df = pull()
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4']], data['Label'])
start_time = time.time()
y_pred = svm_poly.predict(data[['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4']], data['Label'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy  AUC  Recall   Prec.  \
# lr                    Logistic Regression    1.0000  0.0  1.0000  1.0000
# knn                K Neighbors Classifier    1.0000  1.0  1.0000  1.0000
# nb                            Naive Bayes    1.0000  1.0  1.0000  1.0000
# dt               Decision Tree Classifier    1.0000  1.0  1.0000  1.0000
# ridge                    Ridge Classifier    1.0000  0.0  1.0000  1.0000
# rf               Random Forest Classifier    1.0000  1.0  1.0000  1.0000
# ada                  Ada Boost Classifier    1.0000  0.0  1.0000  1.0000
# gbc          Gradient Boosting Classifier    1.0000  0.0  1.0000  1.0000
# lda          Linear Discriminant Analysis    1.0000  0.0  1.0000  1.0000
# et                 Extra Trees Classifier    1.0000  1.0  1.0000  1.0000
# lightgbm  Light Gradient Boosting Machine    1.0000  1.0  1.0000  1.0000
# svm-poly          SVM - Polynomial Kernel    1.0000  NaN  1.0000  1.0000
# svm-rbf                  SVM - RBF Kernel    1.0000  NaN  1.0000  1.0000
# qda       Quadratic Discriminant Analysis    0.9714  0.0  0.9714  0.9857
# svm                   SVM - Linear Kernel    0.6143  0.0  0.6143  0.5464
# dummy                    Dummy Classifier    0.5000  0.5  0.5000  0.2551
#
#               F1   Kappa     MCC   TT (Sec)
# lr        1.0000  1.0000  1.0000   0.008000
# knn       1.0000  1.0000  1.0000   0.008000
# nb        1.0000  1.0000  1.0000   0.005000
# dt        1.0000  1.0000  1.0000   0.005000
# ridge     1.0000  1.0000  1.0000   0.006000
# rf        1.0000  1.0000  1.0000   0.025000
# ada       1.0000  1.0000  1.0000   0.013000
# gbc       1.0000  1.0000  1.0000   0.025000
# lda       1.0000  1.0000  1.0000   0.007000
# et        1.0000  1.0000  1.0000   0.020000
# lightgbm  1.0000  1.0000  1.0000  18.932000
# svm-poly  1.0000  1.0000  1.0000   0.000915
# svm-rbf   1.0000  1.0000  1.0000   0.000992
# qda       0.9728  0.9533  0.9587   0.006000
# svm       0.5518  0.4505  0.5221   0.007000
# dummy     0.3364  0.0000  0.0000   0.005000

# %% [markdown]
# ## 4 Sensors with PCA

# %%
data = pd.read_excel('/home/soham/Desktop/GitHub/BTP/data/4sensors/PCA.xlsx')

clf2 = setup(data, target='Label', session_id=123, verbose=False)
comparison_df = pull()
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['PC1','PC2']], data['Label'])
start_time = time.time()
y_pred = svm_poly.predict(data[['PC1','PC2']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['PC1','PC2']], data['Label'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['PC1','PC2']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy  AUC  Recall   Prec.  \
# lr                    Logistic Regression    1.0000  0.0  1.0000  1.0000
# knn                K Neighbors Classifier    1.0000  1.0  1.0000  1.0000
# nb                            Naive Bayes    1.0000  1.0  1.0000  1.0000
# dt               Decision Tree Classifier    1.0000  1.0  1.0000  1.0000
# ridge                    Ridge Classifier    1.0000  0.0  1.0000  1.0000
# rf               Random Forest Classifier    1.0000  1.0  1.0000  1.0000
# qda       Quadratic Discriminant Analysis    1.0000  0.0  1.0000  1.0000
# ada                  Ada Boost Classifier    1.0000  0.0  1.0000  1.0000
# gbc          Gradient Boosting Classifier    1.0000  0.0  1.0000  1.0000
# lda          Linear Discriminant Analysis    1.0000  0.0  1.0000  1.0000
# et                 Extra Trees Classifier    1.0000  1.0  1.0000  1.0000
# lightgbm  Light Gradient Boosting Machine    1.0000  1.0  1.0000  1.0000
# svm-poly          SVM - Polynomial Kernel    1.0000  NaN  1.0000  1.0000
# svm-rbf                  SVM - RBF Kernel    1.0000  NaN  1.0000  1.0000
# svm                   SVM - Linear Kernel    0.9857  0.0  0.9857  0.9905
# dummy                    Dummy Classifier    0.5000  0.5  0.5000  0.2551
#
#               F1   Kappa     MCC   TT (Sec)
# lr        1.0000  1.0000  1.0000   0.196000
# knn       1.0000  1.0000  1.0000   0.100000
# nb        1.0000  1.0000  1.0000   0.005000
# dt        1.0000  1.0000  1.0000   0.006000
# ridge     1.0000  1.0000  1.0000   0.006000
# rf        1.0000  1.0000  1.0000   0.028000
# qda       1.0000  1.0000  1.0000   0.005000
# ada       1.0000  1.0000  1.0000   0.013000
# gbc       1.0000  1.0000  1.0000   0.025000
# lda       1.0000  1.0000  1.0000   0.005000
# et        1.0000  1.0000  1.0000   0.022000
# lightgbm  1.0000  1.0000  1.0000  19.231000
# svm-poly  1.0000  1.0000  1.0000   0.001048
# svm-rbf   1.0000  1.0000  1.0000   0.000868
# svm       0.9857  0.9788  0.9812   0.006000
# dummy     0.3364  0.0000  0.0000   0.006000

# %% [markdown]
# ## 4 Sensors LDA

# %%
data = pd.read_excel('/home/soham/Desktop/GitHub/BTP/data/4sensors/LDA.xlsx')

clf2 = setup(data, target='Label', session_id=123, verbose=False)
comparison_df = pull()
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['LD1','LD2']], data['Label'])
start_time = time.time()
y_pred = svm_poly.predict(data[['LD1','LD2']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['LD1', 'LD2']], data['Label'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['LD1', 'LD2']])
end_time = time.time()

accuracy = accuracy_score(data['Label'], y_pred)
auc = None
recall = recall_score(data['Label'], y_pred, average='weighted')
precision = precision_score(data['Label'], y_pred, average='weighted')
f1 = f1_score(data['Label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Label'], y_pred)
mcc = matthews_corrcoef(data['Label'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    1.0000  0.0000  1.0000  1.0000
# knn                K Neighbors Classifier    1.0000  1.0000  1.0000  1.0000
# svm                   SVM - Linear Kernel    1.0000  0.0000  1.0000  1.0000
# ridge                    Ridge Classifier    1.0000  0.0000  1.0000  1.0000
# rf               Random Forest Classifier    1.0000  1.0000  1.0000  1.0000
# lda          Linear Discriminant Analysis    1.0000  0.0000  1.0000  1.0000
# et                 Extra Trees Classifier    1.0000  1.0000  1.0000  1.0000
# lightgbm  Light Gradient Boosting Machine    1.0000  1.0000  1.0000  1.0000
# svm-poly          SVM - Polynomial Kernel    1.0000     NaN  1.0000  1.0000
# svm-rbf                  SVM - RBF Kernel    1.0000     NaN  1.0000  1.0000
# dt               Decision Tree Classifier    0.9857  0.9917  0.9857  0.9929
# qda       Quadratic Discriminant Analysis    0.9857  0.0000  0.9857  0.9929
# gbc          Gradient Boosting Classifier    0.9857  0.0000  0.9857  0.9929
# nb                            Naive Bayes    0.9714  0.9988  0.9714  0.9857
# ada                  Ada Boost Classifier    0.9714  0.0000  0.9714  0.9857
# dummy                    Dummy Classifier    0.5000  0.5000  0.5000  0.2551
#
#               F1   Kappa     MCC   TT (Sec)
# lr        1.0000  1.0000  1.0000   0.007000
# knn       1.0000  1.0000  1.0000   0.008000
# svm       1.0000  1.0000  1.0000   0.006000
# ridge     1.0000  1.0000  1.0000   0.006000
# rf        1.0000  1.0000  1.0000   0.025000
# lda       1.0000  1.0000  1.0000   0.005000
# et        1.0000  1.0000  1.0000   0.021000
# lightgbm  1.0000  1.0000  1.0000  19.789000
# svm-poly  1.0000  1.0000  1.0000   0.000919
# svm-rbf   1.0000  1.0000  1.0000   0.000887
# dt        0.9871  0.9774  0.9802   0.005000
# qda       0.9857  0.9759  0.9786   0.005000
# gbc       0.9857  0.9759  0.9786   0.025000
# nb        0.9728  0.9533  0.9587   0.005000
# ada       0.9728  0.9533  0.9587   0.014000
# dummy     0.3364  0.0000  0.0000   0.004000

# %% [markdown]
# ## 3 Sensors

# %%
data = pd.read_csv('/home/soham/Desktop/GitHub/BTP/data/smote/labelled.csv')
data = data[['Sensor1', 'Sensor2', 'Sensor3', 'label']]

clf3 = setup(data, target='label', session_id=123, verbose=False)
comparison_df = pd.DataFrame(pull())
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['Sensor1', 'Sensor2', 'Sensor3']], data['label'])
start_time = time.time()
y_pred = svm_poly.predict(data[['Sensor1', 'Sensor2', 'Sensor3']])
end_time = time.time()

accuracy = accuracy_score(data['label'], y_pred)
auc = None
recall = recall_score(data['label'], y_pred, average='weighted')
precision = precision_score(data['label'], y_pred, average='weighted')
f1 = f1_score(data['label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['label'], y_pred)
mcc = matthews_corrcoef(data['label'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['Sensor1', 'Sensor2', 'Sensor3']], data['label'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['Sensor1', 'Sensor2', 'Sensor3']])
end_time = time.time()

accuracy = accuracy_score(data['label'], y_pred)
auc = None
recall = recall_score(data['label'], y_pred, average='weighted')
precision = precision_score(data['label'], y_pred, average='weighted')
f1 = f1_score(data['label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['label'], y_pred)
mcc = matthews_corrcoef(data['label'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy     AUC  Recall     Prec.  \
# lda          Linear Discriminant Analysis    1.0000  0.0000  1.0000  1.000000
# lr                    Logistic Regression    0.9833  0.0000  0.9833  0.988900
# knn                K Neighbors Classifier    0.9833  0.9833  0.9833  0.988900
# dt               Decision Tree Classifier    0.9833  0.9875  0.9833  0.988900
# rf               Random Forest Classifier    0.9833  1.0000  0.9833  0.988900
# qda       Quadratic Discriminant Analysis    0.9833  0.0000  0.9833  0.988900
# gbc          Gradient Boosting Classifier    0.9833  0.0000  0.9833  0.988900
# et                 Extra Trees Classifier    0.9833  1.0000  0.9833  0.988900
# ada                  Ada Boost Classifier    0.9033  0.0000  0.9033  0.875600
# svm-poly          SVM - Polynomial Kernel    0.8800     NaN  0.8800  0.911765
# svm-rbf                  SVM - RBF Kernel    0.8800     NaN  0.8800  0.911765
# nb                            Naive Bayes    0.8667  0.9833  0.8667  0.910000
# lightgbm  Light Gradient Boosting Machine    0.8500  0.9583  0.8500  0.871100
# ridge                    Ridge Classifier    0.7367  0.0000  0.7367  0.722200
# svm                   SVM - Linear Kernel    0.6933  0.0000  0.6933  0.533300
# dummy                    Dummy Classifier    0.3467  0.5000  0.3467  0.126200
#
#                 F1   Kappa       MCC   TT (Sec)
# lda       1.000000  1.0000  1.000000   0.005000
# lr        0.982200  0.9750  0.978300   0.007000
# knn       0.982200  0.9750  0.978300   0.008000
# dt        0.982200  0.9750  0.978300   0.006000
# rf        0.982200  0.9750  0.978300   0.026000
# qda       0.982200  0.9750  0.978300   0.006000
# gbc       0.982200  0.9750  0.978300   0.028000
# et        0.982200  0.9750  0.978300   0.020000
# ada       0.876900  0.8438  0.868300   0.012000
# svm-poly  0.875982  0.8200  0.838307   0.001145
# svm-rbf   0.875982  0.8200  0.838307   0.000859
# nb        0.864000  0.7993  0.822000   0.005000
# lightgbm  0.845300  0.7724  0.787100  11.198000
# ridge     0.710200  0.6011  0.631800   0.007000
# svm       0.589100  0.5236  0.628000   0.006000
# dummy     0.183800  0.0000  0.000000   0.005000

# %% [markdown]
# ## 3 Sensors PCA

# %%
data = pd.read_excel('/home/soham/Desktop/GitHub/BTP/data/mixture/3 solutions/PCA.xlsx')
data = data[['PC1', 'PC2', 'Labels']]

clf4 = setup(data, target='Labels', session_id=123, verbose=False)
comparison_df = pd.DataFrame(pull())
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['PC1','PC2']], data['Labels'])
start_time = time.time()
y_pred = svm_poly.predict(data[['PC1','PC2']])
end_time = time.time()

accuracy = accuracy_score(data['Labels'], y_pred)
auc = None
recall = recall_score(data['Labels'], y_pred, average='weighted')
precision = precision_score(data['Labels'], y_pred, average='weighted')
f1 = f1_score(data['Labels'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Labels'], y_pred)
mcc = matthews_corrcoef(data['Labels'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['PC1','PC2']], data['Labels'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['PC1','PC2']])
end_time = time.time()

accuracy = accuracy_score(data['Labels'], y_pred)
auc = None
recall = recall_score(data['Labels'], y_pred, average='weighted')
precision = precision_score(data['Labels'], y_pred, average='weighted')
f1 = f1_score(data['Labels'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['Labels'], y_pred)
mcc = matthews_corrcoef(data['Labels'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy     AUC  Recall     Prec.  \
# dt               Decision Tree Classifier    1.0000  1.0000  1.0000  1.000000
# gbc          Gradient Boosting Classifier    1.0000  0.0000  1.0000  1.000000
# lr                    Logistic Regression    0.9833  0.0000  0.9833  0.988900
# knn                K Neighbors Classifier    0.9833  0.9833  0.9833  0.988900
# rf               Random Forest Classifier    0.9833  1.0000  0.9833  0.988900
# et                 Extra Trees Classifier    0.9833  1.0000  0.9833  0.988900
# ada                  Ada Boost Classifier    0.9667  0.0000  0.9667  0.977800
# qda       Quadratic Discriminant Analysis    0.9633  0.0000  0.9633  0.975600
# lightgbm  Light Gradient Boosting Machine    0.9600  0.9942  0.9600  0.953300
# lda          Linear Discriminant Analysis    0.8867  0.0000  0.8867  0.904400
# svm-poly          SVM - Polynomial Kernel    0.8800     NaN  0.8800  0.911765
# svm-rbf                  SVM - RBF Kernel    0.8800     NaN  0.8800  0.911765
# nb                            Naive Bayes    0.8667  0.9867  0.8667  0.877800
# ridge                    Ridge Classifier    0.7767  0.0000  0.7767  0.788900
# svm                   SVM - Linear Kernel    0.6700  0.0000  0.6700  0.578900
# dummy                    Dummy Classifier    0.3467  0.5000  0.3467  0.126200
#
#                 F1   Kappa       MCC   TT (Sec)
# dt        1.000000  1.0000  1.000000   0.005000
# gbc       1.000000  1.0000  1.000000   0.025000
# lr        0.982200  0.9750  0.978300   0.007000
# knn       0.982200  0.9750  0.978300   0.009000
# rf        0.982200  0.9750  0.978300   0.027000
# et        0.982200  0.9750  0.978300   0.023000
# ada       0.964400  0.9500  0.956700   0.013000
# qda       0.960900  0.9438  0.951800   0.005000
# lightgbm  0.950700  0.9354  0.945700  11.105000
# lda       0.872400  0.8229  0.849300   0.005000
# svm-poly  0.875982  0.8200  0.838307   0.000988
# svm-rbf   0.875982  0.8200  0.838307   0.001111
# nb        0.853800  0.7917  0.813300   0.005000
# ridge     0.760900  0.6599  0.692400   0.005000
# svm       0.599100  0.4865  0.544700   0.006000
# dummy     0.183800  0.0000  0.000000   0.004000

# %% [markdown]
# ## 3 Sensors LDA

# %%
data = pd.read_csv('/home/soham/Desktop/GitHub/BTP/data/smote/labelled.csv')
data = data[['Sensor1', 'Sensor2', 'Sensor3', 'label']]

lda = LDA(n_components=2)
X = data[['Sensor1', 'Sensor2', 'Sensor3']]
y = data['label']
lda_data = lda.fit_transform(X, y)
data['LD1'] = lda_data[:, 0]
data['LD2'] = lda_data[:, 1]


data = data[['LD1', 'LD2', 'label']]

clf5 = setup(data, target='label', session_id=123, verbose=False)
comparison_df = pd.DataFrame(pull())
best_model = compare_models()

# %%
# ADDING SVM - POLYNOMIAL MODEL

svm_poly = SVC(kernel='poly', degree=3, C=1, random_state=123)
svm_poly.fit(data[['LD1', 'LD2']], data['label'])
start_time = time.time()
y_pred = svm_poly.predict(data[['LD1', 'LD2']])
end_time = time.time()

accuracy = accuracy_score(data['label'], y_pred)
auc = None
recall = recall_score(data['label'], y_pred, average='weighted')
precision = precision_score(data['label'], y_pred, average='weighted')
f1 = f1_score(data['label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['label'], y_pred)
mcc = matthews_corrcoef(data['label'], y_pred)
tt = end_time - start_time

svm_poly_metrics = {'Model': 'SVM - Polynomial Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# ADDING SVM - RBF MODEL

svm_rbf = SVC(kernel='rbf', C=1, random_state=123)
svm_rbf.fit(data[['LD1', 'LD2']], data['label'])

start_time = time.time()
y_pred = svm_rbf.predict(data[['LD1', 'LD2']])
end_time = time.time()

accuracy = accuracy_score(data['label'], y_pred)
auc = None
recall = recall_score(data['label'], y_pred, average='weighted')
precision = precision_score(data['label'], y_pred, average='weighted')
f1 = f1_score(data['label'], y_pred, average='weighted')
kappa = cohen_kappa_score(data['label'], y_pred)
mcc = matthews_corrcoef(data['label'], y_pred)
tt = end_time - start_time

svm_rbf_metrics = {'Model': 'SVM - RBF Kernel', 'Accuracy': accuracy, 'AUC': auc, 'Recall': recall, 'Prec.': precision, 'F1': f1, 'Kappa': kappa, 'MCC': mcc, 'TT (Sec)': tt}

# %%
comparison_df = pull()
comparison_df.loc['svm-poly'] = svm_poly_metrics
comparison_df.loc['svm-rbf'] = svm_rbf_metrics
comparison_df = comparison_df.sort_values('Accuracy', ascending=False)
comparison_df
# Out:
#                                     Model  Accuracy     AUC    Recall  \
# lr                    Logistic Regression  1.000000  0.0000  1.000000
# knn                K Neighbors Classifier  1.000000  1.0000  1.000000
# dt               Decision Tree Classifier  1.000000  1.0000  1.000000
# rf               Random Forest Classifier  1.000000  1.0000  1.000000
# qda       Quadratic Discriminant Analysis  1.000000  0.0000  1.000000
# ada                  Ada Boost Classifier  1.000000  0.0000  1.000000
# gbc          Gradient Boosting Classifier  1.000000  0.0000  1.000000
# lda          Linear Discriminant Analysis  1.000000  0.0000  1.000000
# lightgbm  Light Gradient Boosting Machine  1.000000  1.0000  1.000000
# svm-rbf                  SVM - RBF Kernel  0.986667     NaN  0.986667
# nb                            Naive Bayes  0.983300  0.9833  0.983300
# et                 Extra Trees Classifier  0.983300  1.0000  0.983300
# svm-poly          SVM - Polynomial Kernel  0.906667     NaN  0.906667
# ridge                    Ridge Classifier  0.773300  0.0000  0.773300
# svm                   SVM - Linear Kernel  0.633300  0.0000  0.633300
# dummy                    Dummy Classifier  0.346700  0.5000  0.346700
#
#              Prec.        F1   Kappa       MCC   TT (Sec)
# lr        1.000000  1.000000  1.0000  1.000000   0.006000
# knn       1.000000  1.000000  1.0000  1.000000   0.010000
# dt        1.000000  1.000000  1.0000  1.000000   0.005000
# rf        1.000000  1.000000  1.0000  1.000000   0.026000
# qda       1.000000  1.000000  1.0000  1.000000   0.005000
# ada       1.000000  1.000000  1.0000  1.000000   0.016000
# gbc       1.000000  1.000000  1.0000  1.000000   0.025000
# lda       1.000000  1.000000  1.0000  1.000000   0.005000
# lightgbm  1.000000  1.000000  1.0000  1.000000  10.736000
# svm-rbf   0.987179  0.986661  0.9800  0.980261   0.000929
# nb        0.988900  0.982200  0.9750  0.978300   0.005000
# et        0.988900  0.982200  0.9750  0.978300   0.020000
# svm-poly  0.927083  0.904801  0.8600  0.871462   0.001370
# ridge     0.763300  0.743600  0.6592  0.695400   0.005000
# svm       0.543300  0.566200  0.4625  0.528700   0.007000
# dummy     0.126200  0.183800  0.0000  0.000000   0.005000
